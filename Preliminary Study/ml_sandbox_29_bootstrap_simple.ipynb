# %% [markdown]
# # Bootstrap Validation — Simple Fixed-Param Models
#
# Tests whether the pipeline's AUC comes from the signal in the data or from the tuning machinery.
#
# For each of **B=100 bootstrap resamples**, three models are fit with **fixed, depth-restricted hyperparameters** on **all 26 features** (no Optuna, no SHAP, no feature selection). Test AUC is evaluated on the fixed held-out test set.
#
# **What this answers:** If AUC distributions here are similar to nb26 (full pipeline, Optuna 10 trials), the signal is in the data and the tuning machinery adds little. If noticeably lower, the pipeline earns its complexity.
#
# **Simplifications vs nb21/nb26:**
# - No Optuna — fixed reasonable params with depth restriction
# - No feature selection — all 26 features used
# - No genre consolidation, no centrality ablation
#
# **Models:** CatBoost · XGBoost · Random Forest · Stratified Baseline
# Results saved to `bootstrap_simple_results.pkl` after every iteration.

# %%
import warnings
warnings.filterwarnings('ignore')

import logging
logging.getLogger('lightgbm').setLevel(logging.ERROR)

import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
import matplotlib.gridspec as gridspec

import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score, brier_score_loss
from sklearn.model_selection import train_test_split, StratifiedKFold

from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
B            = 100
RANDOM_STATE = 42
BOOT_MODELS  = ['CatBoost', 'XGBoost', 'Random Forest']

# nb21 single-run test AUC — reference lines on histograms
NB21_AUC = {
    'CatBoost':      0.7533,
    'XGBoost':       0.7742,
    'Random Forest': 0.7671,
}

# Fixed params — depth-restricted, no tuning
FIXED_PARAMS = {
    'Random Forest': {
        'n_estimators': 200,
        'max_depth':    5,
        'min_samples_leaf': 5,
        'max_features': 'sqrt',
        'class_weight': 'balanced',
        'random_state': RANDOM_STATE,
        'n_jobs': -1,
    },
    'XGBoost': {
        'n_estimators':  200,
        'learning_rate': 0.05,
        'max_depth':     3,
        'subsample':     0.8,
        'colsample_bytree': 0.8,
        'random_state':  RANDOM_STATE,
        'eval_metric':   'logloss',
        'verbosity':     0,
    },
    'CatBoost': {
        'iterations':    200,
        'learning_rate': 0.05,
        'depth':         4,
        'random_seed':   RANDOM_STATE,
        'verbose':       0,
    },
}

df = pd.read_csv('../df_artists_final.csv', index_col=0).reset_index()
X  = df.drop(columns=['top_20_hitmaker'])
y  = df['top_20_hitmaker']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=RANDOM_STATE, stratify=y
)

print(f'Train: {X_train.shape}  Test: {X_test.shape}')
print(f'Class balance (train): {y_train.mean():.3f} hitmaker')
# Out:
# Train: (607, 26)  Test: (152, 26)
# Class balance (train): 0.432 hitmaker

# %%
def build_model(name):
    p = FIXED_PARAMS[name]
    if name == 'Random Forest':
        return RandomForestClassifier(**p)
    elif name == 'XGBoost':
        return XGBClassifier(**p)
    elif name == 'CatBoost':
        return CatBoostClassifier(**p)
    raise ValueError(f'Unknown model: {name}')


def run_one_model(name, X_tr, y_tr, X_te, y_te):
    imp      = SimpleImputer(strategy='median')
    X_tr_imp = pd.DataFrame(imp.fit_transform(X_tr), columns=X_tr.columns)
    X_te_imp = pd.DataFrame(imp.transform(X_te),     columns=X_te.columns)

    model = build_model(name)
    model.fit(X_tr_imp, y_tr)

    train_proba = model.predict_proba(X_tr_imp)[:, 1]
    test_proba  = model.predict_proba(X_te_imp)[:, 1]

    train_auc = roc_auc_score(y_tr, train_proba)
    test_auc  = roc_auc_score(y_te, test_proba)

    return {
        'test_auc':  test_auc,
        'train_auc': train_auc,
        'gap':       train_auc - test_auc,
        'brier':     brier_score_loss(y_te, test_proba),
    }

# %%
imp = SimpleImputer(strategy='median')
X_train_imp = pd.DataFrame(imp.fit_transform(X_train), columns=X_train.columns)
X_test_imp  = pd.DataFrame(imp.transform(X_test),      columns=X_test.columns)

print(f'{"Model":<20}  {"Train AUC":>10}  {"Test AUC":>10}  {"Gap":>8}')
print('─' * 55)

for name in BOOT_MODELS:
    model = build_model(name)
    model.fit(X_train_imp, y_train)
    train_auc = roc_auc_score(y_train, model.predict_proba(X_train_imp)[:, 1])
    test_auc  = roc_auc_score(y_test,  model.predict_proba(X_test_imp)[:, 1])
    gap       = train_auc - test_auc
    print(f'{name:<20}  {train_auc:>10.4f}  {test_auc:>10.4f}  {gap:>8.4f}')
# Out:
# Model                  Train AUC    Test AUC       Gap
# ───────────────────────────────────────────────────────
# CatBoost                  0.9312      0.7820    0.1493
# XGBoost                   0.9261      0.7712    0.1549
# Random Forest             0.8550      0.7753    0.0797

# %% [markdown]
# ## Bootstrap loop
#
# B=100 independent iterations. Saved to `bootstrap_simple_results.pkl` after every iteration.

# %%
results = {name: {'test_auc': [], 'train_auc': [], 'gap': [], 'brier': []} for name in BOOT_MODELS}
results['Baseline'] = {'test_auc': [], 'brier': []}

rng = np.random.default_rng(RANDOM_STATE)

for b in range(B):
    seed     = RANDOM_STATE + b
    boot_idx = rng.choice(len(X_train), size=len(X_train), replace=True)
    X_tr_b   = X_train.iloc[boot_idx].reset_index(drop=True)
    y_tr_b   = y_train.iloc[boot_idx].reset_index(drop=True)

    print(f'[{b+1:03d}/{B}] ', end='', flush=True)

    for name in BOOT_MODELS:
        print(f'{name}... ', end='', flush=True)
        try:
            res = run_one_model(name, X_tr_b, y_tr_b, X_test, y_test)
            results[name]['test_auc'].append(res['test_auc'])
            results[name]['train_auc'].append(res['train_auc'])
            results[name]['gap'].append(res['gap'])
            results[name]['brier'].append(res['brier'])
            print(f'AUC={res["test_auc"]:.3f} gap={res["gap"]:.3f} | ', end='', flush=True)
        except Exception as e:
            print(f'ERROR({e}) | ', end='', flush=True)
            for k in ('test_auc', 'train_auc', 'gap', 'brier'):
                results[name][k].append(np.nan)

    dummy = DummyClassifier(strategy='stratified', random_state=seed)
    dummy.fit(X_tr_b, y_tr_b)
    dummy_proba = dummy.predict_proba(X_test)[:, 1]
    results['Baseline']['test_auc'].append(roc_auc_score(y_test, dummy_proba))
    results['Baseline']['brier'].append(brier_score_loss(y_test, dummy_proba))
    print(f'Baseline={results["Baseline"]["test_auc"][-1]:.3f}')

    with open('bootstrap_simple_results.pkl', 'wb') as f:
        pickle.dump(results, f)

print('\nDone. Results saved to bootstrap_simple_results.pkl')
# Out:
# [001/100] CatBoost... AUC=0.747 gap=0.211 | XGBoost... AUC=0.718 gap=0.234 | Random Forest... AUC=0.732 gap=0.165 | Baseline=0.492
# [002/100] CatBoost... AUC=0.784 gap=0.193 | XGBoost... AUC=0.749 gap=0.218 | Random Forest... AUC=0.769 gap=0.137 | Baseline=0.506
# [003/100] CatBoost... AUC=0.798 gap=0.174 | XGBoost... AUC=0.782 gap=0.181 | Random Forest... AUC=0.783 gap=0.131 | Baseline=0.501
# [004/100] CatBoost... AUC=0.767 gap=0.206 | XGBoost... AUC=0.742 gap=0.219 | Random Forest... AUC=0.772 gap=0.126 | Baseline=0.511
# [005/100] CatBoost... AUC=0.741 gap=0.231 | XGBoost... AUC=0.723 gap=0.241 | Random Forest... AUC=0.736 gap=0.162 | Baseline=0.502
# [006/100] CatBoost... AUC=0.766 gap=0.203 | XGBoost... AUC=0.753 gap=0.211 | Random Forest... AUC=0.764 gap=0.130 | Baseline=0.522
# [007/100] CatBoost... AUC=0.760 gap=0.220 | XGBoost... AUC=0.766 gap=0.204 | Random Forest... AUC=0.769 gap=0.145 | Baseline=0.463
# [008/100] CatBoost... AUC=0.765 gap=0.208 | XGBoost... AUC=0.747 gap=0.215 | Random Forest... AUC=0.749 gap=0.150 | Baseline=0.519
# [009/100] CatBoost... AUC=0.738 gap=0.240 | XGBoost... AUC=0.734 gap=0.234 | Random Forest... AUC=0.737 gap=0.174 | Baseline=0.493
# [010/100] CatBoost... AUC=0.766 gap=0.208 | XGBoost... AUC=0.757 gap=0.209 | Random Forest... AUC=0.763 gap=0.145 | Baseline=0.543
# [011/100] CatBoost... AUC=0.746 gap=0.224 | XGBoost... AUC=0.720 gap=0.242 | Random Forest... AUC=0.741 gap=0.157 | Baseline=0.422
# [012/100] CatBoost... AUC=0.787 gap=0.184 | XGBoost... AUC=0.747 gap=0.212 | Random Forest... AUC=0.766 gap=0.134 | Baseline=0.435
# [013/100] CatBoost... AUC=0.787 gap=0.191 | XGBoost... AUC=0.782 gap=0.185 | Random Forest... AUC=0.784 gap=0.127 | Baseline=0.505
# [014/100] CatBoost... AUC=0.774 gap=0.196 | XGBoost... AUC=0.762 gap=0.199 | Random Forest... AUC=0.756 gap=0.132 | Baseline=0.436
# [015/100] CatBoost... AUC=0.749 gap=0.218 | XGBoost... AUC=0.731 gap=0.229 | Random Forest... AUC=0.751 gap=0.153 | Baseline=0.524
# [016/100] CatBoost... AUC=0.750 gap=0.226 | XGBoost... AUC=0.751 gap=0.219 | Random Forest... AUC=0.762 gap=0.138 | Baseline=0.603
# [017/100] CatBoost... AUC=0.763 gap=0.206 | XGBoost... AUC=0.755 gap=0.206 | Random Forest... AUC=0.762 gap=0.143 | Baseline=0.509
# [018/100] CatBoost... AUC=0.756 gap=0.214 | XGBoost... AUC=0.742 gap=0.215 | Random Forest... AUC=0.768 gap=0.135 | Baseline=0.510
# [019/100] CatBoost... AUC=0.780 gap=0.198 | XGBoost... AUC=0.749 gap=0.222 | Random Forest... AUC=0.781 gap=0.127 | Baseline=0.478
# [020/100] CatBoost... AUC=0.740 gap=0.222 | XGBoost... AUC=0.727 gap=0.230 | Random Forest... AUC=0.743 gap=0.140 | Baseline=0.599
# [021/100] CatBoost... AUC=0.784 gap=0.190 | XGBoost... AUC=0.763 gap=0.200 | Random Forest... AUC=0.757 gap=0.145 | Baseline=0.528
# [022/100] CatBoost... AUC=0.765 gap=0.207 | XGBoost... AUC=0.756 gap=0.208 | Random Forest... AUC=0.760 gap=0.151 | Baseline=0.521
# [023/100] CatBoost... AUC=0.768 gap=0.203 | XGBoost... AUC=0.767 gap=0.194 | Random Forest... AUC=0.766 gap=0.137 | Baseline=0.536
# [024/100] CatBoost... AUC=0.775 gap=0.194 | XGBoost... AUC=0.760 gap=0.201 | Random Forest... AUC=0.762 gap=0.144 | Baseline=0.486
# [025/100] CatBoost... AUC=0.770 gap=0.201 | XGBoost... AUC=0.730 gap=0.234 | Random Forest... AUC=0.754 gap=0.145 | Baseline=0.498
# [026/100] CatBoost... AUC=0.739 gap=0.246 | XGBoost... AUC=0.742 gap=0.231 | Random Forest... AUC=0.741 gap=0.169 | Baseline=0.553
# [027/100] CatBoost... AUC=0.765 gap=0.208 | XGBoost... AUC=0.749 gap=0.216 | Random Forest... AUC=0.753 gap=0.162 | Baseline=0.513
# [028/100] CatBoost... AUC=0.740 gap=0.235 | XGBoost... AUC=0.744 gap=0.224 | Random Forest... AUC=0.746 gap=0.180 | Baseline=0.473
# [029/100] CatBoost... AUC=0.759 gap=0.211 | XGBoost... AUC=0.748 gap=0.212 | Random Forest... AUC=0.752 gap=0.156 | Baseline=0.507
# [030/100] CatBoost... AUC=0.763 gap=0.218 | XGBoost... AUC=0.780 gap=0.192 | Random Forest... AUC=0.763 gap=0.157 | Baseline=0.447
# [031/100] CatBoost... AUC=0.787 gap=0.193 | XGBoost... AUC=0.771 gap=0.205 | Random Forest... AUC=0.768 gap=0.152 | Baseline=0.566
# [032/100] CatBoost... AUC=0.756 gap=0.207 | XGBoost... AUC=0.748 gap=0.209 | Random Forest... AUC=0.749 gap=0.146 | Baseline=0.468
# [033/100] CatBoost... AUC=0.764 gap=0.206 | XGBoost... AUC=0.744 gap=0.215 | Random Forest... AUC=0.767 gap=0.132 | Baseline=0.520
# [034/100] CatBoost... AUC=0.773 gap=0.191 | XGBoost... AUC=0.761 gap=0.194 | Random Forest... AUC=0.770 gap=0.127 | Baseline=0.521
# [035/100] CatBoost... AUC=0.777 gap=0.188 | XGBoost... AUC=0.757 gap=0.201 | Random Forest... AUC=0.771 gap=0.126 | Baseline=0.509
# [036/100] CatBoost... AUC=0.767 gap=0.208 | XGBoost... AUC=0.768 gap=0.199 | Random Forest... AUC=0.774 gap=0.125 | Baseline=0.501
# [037/100] CatBoost... AUC=0.766 gap=0.211 | XGBoost... AUC=0.738 gap=0.231 | Random Forest... AUC=0.744 gap=0.164 | Baseline=0.447
# [038/100] CatBoost... AUC=0.774 gap=0.187 | XGBoost... AUC=0.733 gap=0.221 | Random Forest... AUC=0.743 gap=0.149 | Baseline=0.496
# [039/100] CatBoost... AUC=0.755 gap=0.212 | XGBoost... AUC=0.744 gap=0.215 | Random Forest... AUC=0.759 gap=0.152 | Baseline=0.472
# [040/100] CatBoost... AUC=0.770 gap=0.196 | XGBoost... AUC=0.747 gap=0.212 | Random Forest... AUC=0.747 gap=0.141 | Baseline=0.498
# [041/100] CatBoost... AUC=0.793 gap=0.177 | XGBoost... AUC=0.791 gap=0.173 | Random Forest... AUC=0.776 gap=0.133 | Baseline=0.556
# [042/100] CatBoost... AUC=0.777 gap=0.204 | XGBoost... AUC=0.748 gap=0.224 | Random Forest... AUC=0.771 gap=0.154 | Baseline=0.507
# [043/100] CatBoost... AUC=0.759 gap=0.208 | XGBoost... AUC=0.736 gap=0.219 | Random Forest... AUC=0.752 gap=0.138 | Baseline=0.500
# [044/100] CatBoost... AUC=0.755 gap=0.225 | XGBoost... AUC=0.731 gap=0.240 | Random Forest... AUC=0.753 gap=0.167 | Baseline=0.482
# [045/100] CatBoost... AUC=0.728 gap=0.241 | XGBoost... AUC=0.736 gap=0.229 | Random Forest... AUC=0.746 gap=0.160 | Baseline=0.485
# [046/100] CatBoost... AUC=0.755 gap=0.222 | XGBoost... AUC=0.759 gap=0.210 | Random Forest... AUC=0.755 gap=0.151 | Baseline=0.516
# [047/100] CatBoost... AUC=0.754 gap=0.215 | XGBoost... AUC=0.743 gap=0.216 | Random Forest... AUC=0.767 gap=0.126 | Baseline=0.476
# [048/100] CatBoost... AUC=0.740 gap=0.225 | XGBoost... AUC=0.727 gap=0.232 | Random Forest... AUC=0.746 gap=0.155 | Baseline=0.564
# [049/100] CatBoost... AUC=0.775 gap=0.202 | XGBoost... AUC=0.767 gap=0.198 | Random Forest... AUC=0.765 gap=0.134 | Baseline=0.497
# [050/100] CatBoost... AUC=0.761 gap=0.204 | XGBoost... AUC=0.732 gap=0.227 | Random Forest... AUC=0.765 gap=0.133 | Baseline=0.585
# [051/100] CatBoost... AUC=0.741 gap=0.229 | XGBoost... AUC=0.725 gap=0.239 | Random Forest... AUC=0.739 gap=0.157 | Baseline=0.530
# [052/100] CatBoost... AUC=0.752 gap=0.228 | XGBoost... AUC=0.693 gap=0.276 | Random Forest... AUC=0.750 gap=0.172 | Baseline=0.501
# [053/100] CatBoost... AUC=0.766 gap=0.215 | XGBoost... AUC=0.751 gap=0.218 | Random Forest... AUC=0.766 gap=0.154 | Baseline=0.514
# [054/100] CatBoost... AUC=0.756 gap=0.220 | XGBoost... AUC=0.712 gap=0.250 | Random Forest... AUC=0.756 gap=0.151 | Baseline=0.463
# [055/100] CatBoost... AUC=0.752 gap=0.228 | XGBoost... AUC=0.734 gap=0.229 | Random Forest... AUC=0.761 gap=0.145 | Baseline=0.547
# [056/100] CatBoost... AUC=0.763 gap=0.202 | XGBoost... AUC=0.753 gap=0.204 | Random Forest... AUC=0.760 gap=0.138 | Baseline=0.514
# [057/100] CatBoost... AUC=0.732 gap=0.243 | XGBoost... AUC=0.741 gap=0.227 | Random Forest... AUC=0.752 gap=0.164 | Baseline=0.486
# [058/100] CatBoost... AUC=0.722 gap=0.237 | XGBoost... AUC=0.705 gap=0.248 | Random Forest... AUC=0.735 gap=0.156 | Baseline=0.531
# [059/100] CatBoost... AUC=0.768 gap=0.210 | XGBoost... AUC=0.751 gap=0.217 | Random Forest... AUC=0.764 gap=0.148 | Baseline=0.447
# [060/100] CatBoost... AUC=0.756 gap=0.220 | XGBoost... AUC=0.741 gap=0.220 | Random Forest... AUC=0.763 gap=0.135 | Baseline=0.473
# [061/100] CatBoost... AUC=0.755 gap=0.219 | XGBoost... AUC=0.726 gap=0.237 | Random Forest... AUC=0.745 gap=0.148 | Baseline=0.506
# [062/100] CatBoost... AUC=0.804 gap=0.167 | XGBoost... AUC=0.797 gap=0.165 | Random Forest... AUC=0.772 gap=0.138 | Baseline=0.510
# [063/100] CatBoost... AUC=0.750 gap=0.211 | XGBoost... AUC=0.734 gap=0.218 | Random Forest... AUC=0.757 gap=0.138 | Baseline=0.489
# [064/100] CatBoost... AUC=0.764 gap=0.203 | XGBoost... AUC=0.760 gap=0.202 | Random Forest... AUC=0.760 gap=0.141 | Baseline=0.527
# [065/100] CatBoost... AUC=0.760 gap=0.213 | XGBoost... AUC=0.746 gap=0.219 | Random Forest... AUC=0.756 gap=0.154 | Baseline=0.509
# [066/100] CatBoost... AUC=0.742 gap=0.233 | XGBoost... AUC=0.739 gap=0.223 | Random Forest... AUC=0.778 gap=0.137 | Baseline=0.576
# [067/100] CatBoost... AUC=0.748 gap=0.226 | XGBoost... AUC=0.748 gap=0.217 | Random Forest... AUC=0.741 gap=0.172 | Baseline=0.516
# [068/100] CatBoost... AUC=0.749 gap=0.211 | XGBoost... AUC=0.743 gap=0.213 | Random Forest... AUC=0.744 gap=0.145 | Baseline=0.450
# [069/100] CatBoost... AUC=0.751 gap=0.221 | XGBoost... AUC=0.760 gap=0.206 | Random Forest... AUC=0.769 gap=0.136 | Baseline=0.463
# [070/100] CatBoost... AUC=0.749 gap=0.222 | XGBoost... AUC=0.738 gap=0.226 | Random Forest... AUC=0.776 gap=0.122 | Baseline=0.485
# [071/100] CatBoost... AUC=0.767 gap=0.211 | XGBoost... AUC=0.758 gap=0.211 | Random Forest... AUC=0.783 gap=0.125 | Baseline=0.461
# [072/100] CatBoost... AUC=0.771 gap=0.193 | XGBoost... AUC=0.760 gap=0.193 | Random Forest... AUC=0.758 gap=0.128 | Baseline=0.530
# [073/100] CatBoost... AUC=0.780 gap=0.187 | XGBoost... AUC=0.766 gap=0.193 | Random Forest... AUC=0.790 gap=0.101 | Baseline=0.469
# [074/100] CatBoost... AUC=0.770 gap=0.208 | XGBoost... AUC=0.763 gap=0.206 | Random Forest... AUC=0.766 gap=0.135 | Baseline=0.509
# [075/100] CatBoost... AUC=0.768 gap=0.203 | XGBoost... AUC=0.742 gap=0.219 | Random Forest... AUC=0.761 gap=0.148 | Baseline=0.543
# [076/100] CatBoost... AUC=0.735 gap=0.245 | XGBoost... AUC=0.735 gap=0.231 | Random Forest... AUC=0.745 gap=0.162 | Baseline=0.470
# [077/100] CatBoost... AUC=0.770 gap=0.208 | XGBoost... AUC=0.767 gap=0.202 | Random Forest... AUC=0.762 gap=0.152 | Baseline=0.484
# [078/100] CatBoost... AUC=0.731 gap=0.246 | XGBoost... AUC=0.732 gap=0.234 | Random Forest... AUC=0.768 gap=0.147 | Baseline=0.517
# [079/100] CatBoost... AUC=0.755 gap=0.206 | XGBoost... AUC=0.759 gap=0.190 | Random Forest... AUC=0.753 gap=0.135 | Baseline=0.499
# [080/100] CatBoost... AUC=0.729 gap=0.242 | XGBoost... AUC=0.702 gap=0.254 | Random Forest... AUC=0.748 gap=0.141 | Baseline=0.514
# [081/100] CatBoost... AUC=0.781 gap=0.183 | XGBoost... AUC=0.777 gap=0.177 | Random Forest... AUC=0.767 gap=0.136 | Baseline=0.505
# [082/100] CatBoost... AUC=0.761 gap=0.208 | XGBoost... AUC=0.751 gap=0.210 | Random Forest... AUC=0.744 gap=0.143 | Baseline=0.530
# [083/100] CatBoost... AUC=0.756 gap=0.210 | XGBoost... AUC=0.755 gap=0.204 | Random Forest... AUC=0.762 gap=0.122 | Baseline=0.525
# [084/100] CatBoost... AUC=0.749 gap=0.219 | XGBoost... AUC=0.731 gap=0.236 | Random Forest... AUC=0.768 gap=0.147 | Baseline=0.511
# [085/100] CatBoost... AUC=0.770 gap=0.209 | XGBoost... AUC=0.783 gap=0.185 | Random Forest... AUC=0.783 gap=0.134 | Baseline=0.477
# [086/100] CatBoost... AUC=0.760 gap=0.214 | XGBoost... AUC=0.731 gap=0.230 | Random Forest... AUC=0.758 gap=0.148 | Baseline=0.495
# [087/100] CatBoost... AUC=0.760 gap=0.217 | XGBoost... AUC=0.756 gap=0.208 | Random Forest... AUC=0.768 gap=0.144 | Baseline=0.512
# [088/100] CatBoost... AUC=0.784 gap=0.182 | XGBoost... AUC=0.786 gap=0.172 | Random Forest... AUC=0.774 gap=0.121 | Baseline=0.555
# [089/100] CatBoost... AUC=0.772 gap=0.210 | XGBoost... AUC=0.764 gap=0.211 | Random Forest... AUC=0.760 gap=0.156 | Baseline=0.572
# [090/100] CatBoost... AUC=0.787 gap=0.185 | XGBoost... AUC=0.771 gap=0.191 | Random Forest... AUC=0.775 gap=0.135 | Baseline=0.588
# [091/100] CatBoost... AUC=0.788 gap=0.183 | XGBoost... AUC=0.776 gap=0.192 | Random Forest... AUC=0.776 gap=0.137 | Baseline=0.512
# [092/100] CatBoost... AUC=0.778 gap=0.191 | XGBoost... AUC=0.765 gap=0.197 | Random Forest... AUC=0.773 gap=0.126 | Baseline=0.510
# [093/100] CatBoost... AUC=0.764 gap=0.203 | XGBoost... AUC=0.739 gap=0.219 | Random Forest... AUC=0.749 gap=0.146 | Baseline=0.460
# [094/100] CatBoost... AUC=0.795 gap=0.179 | XGBoost... AUC=0.771 gap=0.192 | Random Forest... AUC=0.778 gap=0.124 | Baseline=0.475
# [095/100] CatBoost... AUC=0.748 gap=0.230 | XGBoost... AUC=0.726 gap=0.242 | Random Forest... AUC=0.752 gap=0.160 | Baseline=0.505
# [096/100] CatBoost... AUC=0.788 gap=0.187 | XGBoost... AUC=0.748 gap=0.212 | Random Forest... AUC=0.757 gap=0.146 | Baseline=0.484
# [097/100] CatBoost... AUC=0.752 gap=0.218 | XGBoost... AUC=0.753 gap=0.210 | Random Forest... AUC=0.766 gap=0.140 | Baseline=0.492
# [098/100] CatBoost... AUC=0.744 gap=0.232 | XGBoost... AUC=0.754 gap=0.213 | Random Forest... AUC=0.766 gap=0.134 | Baseline=0.546
# [099/100] CatBoost... AUC=0.790 gap=0.173 | XGBoost... AUC=0.761 gap=0.194 | Random Forest... AUC=0.766 gap=0.130 | Baseline=0.489
# [100/100] CatBoost... AUC=0.762 gap=0.213 | XGBoost... AUC=0.767 gap=0.200 | Random Forest... AUC=0.767 gap=0.138 | Baseline=0.566
#
# Done. Results saved to bootstrap_simple_results.pkl

# %% [markdown]
# ## Results
#
# **Reading the histograms:**
# - Dashed line = bootstrap mean · Shaded band = 90% CI · Dotted line = nb21 single-run AUC
# - Simple mean ≈ nb21 tuned mean → tuning adds little; signal is in the data
# - Simple mean notably lower → pipeline tuning is earning its complexity
# - All model distributions clearly above Baseline → real signal, not noise

# %%
with open('bootstrap_simple_results.pkl', 'rb') as f:
    results = pickle.load(f)

# nb26 means for comparison
NB26_MEAN = {
    'CatBoost':      0.7187,
    'XGBoost':       0.7391,
    'Random Forest': 0.7447,
}

all_names = BOOT_MODELS + ['Baseline']
palette = {
    'CatBoost':      '#4C72B0',
    'XGBoost':       '#DD8452',
    'Random Forest': '#55A868',
    'Baseline':      '#aaaaaa',
}

xlim_auc = (0.40, 0.90)
x_auc    = np.linspace(*xlim_auc, 300)

baseline_aucs = [v for v in results['Baseline']['test_auc'] if not np.isnan(v)]
baseline_mean = np.mean(baseline_aucs)

fig = plt.figure(figsize=(18, 10))
gs  = gridspec.GridSpec(2, 4, figure=fig, hspace=0.55, wspace=0.30)

top_axes    = [fig.add_subplot(gs[0, col]) for col in range(4)]
ax_combined = fig.add_subplot(gs[1, :])

fig.suptitle(
    f'Bootstrap Validation — Simple Fixed-Param Models  (B={B})\n'
    'No Optuna, no feature selection — depth-restricted defaults on all 26 features.',
    fontsize=13, fontweight='bold')

# ── Row 1: Test AUC histograms ──
for col, name in enumerate(all_names):
    ax   = top_axes[col]
    vals = [v for v in results[name]['test_auc'] if not np.isnan(v)]
    if not vals:
        ax.set_title(f'{name}\n(no data)'); continue

    color = palette[name]
    mu    = np.mean(vals)
    p5    = np.percentile(vals, 5)
    p95   = np.percentile(vals, 95)

    ax.hist(vals, bins=15, color=color, alpha=0.35, density=True)
    kde   = gaussian_kde(vals, bw_method='scott')
    y_kde = kde(x_auc)
    ax.plot(x_auc, y_kde, color=color, lw=2.0)

    mask = (x_auc >= p5) & (x_auc <= p95)
    ax.fill_between(x_auc[mask], y_kde[mask], alpha=0.30, color=color,
                    label=f'90% CI [{p5:.3f}, {p95:.3f}]')
    ax.axvline(mu, color=color, lw=2.0, linestyle='--', label=f'mean={mu:.3f}')
    if name in NB21_AUC:
        ax.axvline(NB21_AUC[name], color='black', lw=1.5, linestyle=':',
                   label=f'nb21={NB21_AUC[name]:.3f}')
    if name in NB26_MEAN:
        ax.axvline(NB26_MEAN[name], color='grey', lw=1.5, linestyle='--',
                   label=f'nb26={NB26_MEAN[name]:.3f}')

    if name in BOOT_MODELS:
        gap_vs_base = mu - baseline_mean
        ax.text(0.97, 0.95, f'{gap_vs_base:+.3f} vs baseline',
                transform=ax.transAxes, ha='right', va='top', fontsize=8,
                color=color, bbox=dict(boxstyle='round,pad=0.3', facecolor='white',
                                       edgecolor=color, alpha=0.85))

    ax.set_xlabel('Test AUC', fontsize=9)
    ax.set_ylabel('Density' if col == 0 else '', fontsize=9)
    ax.set_title(f'{name}\nTest AUC', fontweight='bold')
    ax.set_xlim(xlim_auc)
    ax.legend(fontsize=7)
    ax.grid(True, alpha=0.3)

# ── Row 2: Combined AUC overlay ──
for name in BOOT_MODELS:
    vals = [v for v in results[name]['test_auc'] if not np.isnan(v)]
    if not vals: continue
    color = palette[name]
    mu    = np.mean(vals)
    kde   = gaussian_kde(vals, bw_method='scott')
    y_kde = kde(x_auc)
    ax_combined.plot(x_auc, y_kde, color=color, lw=2.5,
                     label=f'{name}  (mean={mu:.3f})')
    ax_combined.fill_between(x_auc, y_kde, alpha=0.12, color=color)
    ax_combined.axvline(mu, color=color, lw=1.5, linestyle='--', alpha=0.7)

ax_combined.axvline(baseline_mean, color='#888888', lw=1.5, linestyle=':',
                    label=f'Baseline mean={baseline_mean:.3f}')
ax_combined.set_xlabel('Test AUC', fontsize=10)
ax_combined.set_ylabel('Density', fontsize=10)
ax_combined.set_title('All Models — Combined Test AUC Distributions', fontweight='bold')
ax_combined.set_xlim(xlim_auc)
ax_combined.legend(fontsize=9)
ax_combined.grid(True, alpha=0.3)

plt.savefig('bootstrap_simple_plot.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
print(f'{"Model":<20}  {"AUC mean":>8}  {"AUC std":>8}  {"90% CI":>22}  {"Brier":>7}  {"B":>5}')
print('─' * 80)

for name in all_names:
    aucs   = [v for v in results[name]['test_auc'] if not np.isnan(v)]
    briers = [v for v in results[name]['brier']    if not np.isnan(v)]
    if not aucs: continue
    ci = f'[{np.percentile(aucs, 5):.3f}, {np.percentile(aucs, 95):.3f}]'
    print(f'{name:<20}  {np.mean(aucs):>8.4f}  {np.std(aucs):>8.4f}  {ci:>22}  {np.mean(briers):>7.4f}  {len(aucs):>5d}')

print()
print('Comparison vs nb26 (full pipeline, Optuna 10 trials):')
for name in BOOT_MODELS:
    aucs = [v for v in results[name]['test_auc'] if not np.isnan(v)]
    if aucs and name in NB26_MEAN:
        delta = np.mean(aucs) - NB26_MEAN[name]
        note  = '  tuning adds little' if abs(delta) < 0.01 else (
                '  simple wins (!)' if delta > 0.01 else '  tuning helps')
        print(f'  {name:<20}  simple={np.mean(aucs):.4f}  nb26={NB26_MEAN[name]:.4f}  delta={delta:+.4f}{note}')
# Out:
# Model                 AUC mean   AUC std                  90% CI    Brier      B
# ────────────────────────────────────────────────────────────────────────────────
# CatBoost                0.7622    0.0166          [0.735, 0.788]   0.1945    100
# XGBoost                 0.7490    0.0190          [0.720, 0.782]   0.2022    100
# Random Forest           0.7602    0.0124          [0.741, 0.781]   0.1989    100
# Baseline                0.5064    0.0355          [0.447, 0.572]   0.4837    100
#
# Comparison vs nb26 (full pipeline, Optuna 10 trials):
#   CatBoost              simple=0.7622  nb26=0.7187  delta=+0.0435  simple wins (!)
#   XGBoost               simple=0.7490  nb26=0.7391  delta=+0.0099  tuning adds little
#   Random Forest         simple=0.7602  nb26=0.7447  delta=+0.0155  simple wins (!)
